# %% [markdown]
# <a href="https://colab.research.google.com/github/rawanmohammed277/CNN_Face-Mask-Detection/blob/main/Face_Mask_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
from keras.preprocessing import image

# %%
categories=['No Mask' , 'Mask']
